# %%
from ultralytics import YOLO

model = YOLO('/home/julianzu/Analytics/Ultilitycs/test 08 may/models/bestfutbol.pt')

results = model.predict('/home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4', save = True)
print(results[0])
for box in results[0].boxes:
    print(box)
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (1/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 38 players, 674.3ms
# video 1/1 (2/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 42 players, 224.4ms
# video 1/1 (3/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 43 players, 200.6ms
# ...

# %%
print(results[0])
for box in results[0].boxes:
    print(box)
# Out:
# ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# ...

# %%
import random
import matplotlib.pyplot as plt

# Cargar el modelo
model = YOLO('yolov8m', task='segm')  # Asegúrate de especificar el task adecuado si es necesario

# Realizar la predicción
results = model.predict('input_videos/drone trimmed.mp4', save = True)

# Asegurarse de que hay detecciones con máscaras
if 'masks' in results.attr and len(results.masks) > 0:
    # Elegir una máscara aleatoria
    random_index = random.randint(0, len(results.masks) - 1)
    mask = results.masks[random_index]

    # Visualizar la máscara
    plt.imshow(mask, cmap='gray')
    plt.title('Random Object Mask')
    plt.axis('off')
    plt.show()
else:
    print("No masks found in the results.")
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (1/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 13 persons, 797.5ms
# video 1/1 (2/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 13 persons, 777.1ms
# video 1/1 (3/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 16 persons, 708.6ms
# ...

# %% [markdown]
# # GET Dataset

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="4YFYl0cqYo11ij1eu1yZ")
project = rf.workspace("loicaudl").project("audldiscdetection")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.196 is required but found version=8.1.10, to fix: `pip install ultralytics==8.0.196`
# ...
# Extracting Dataset Version Zip to AUDLDiscDetection-1 in yolov8:: 100%|██████████| 370/370 [00:01<00:00, 324.79it/s]

# %%
import shutil

shutil.move('Analytics/Ultilitycs/test 08 may/AUDLDiscDetection-1/train',
            'Analytics/Ultilitycs/test 08 may/AUDLDiscDetection-1/AUDLDiscDetection-1/train')

shutil.move('Analytics/Ultilitycs/test 08 may/AUDLDiscDetection-1/test',
            'Analytics/Ultilitycs/test 08 may/AUDLDiscDetection-1/AUDLDiscDetection-1/test')

shutil.move('Analytics/Ultilitycs/test 08 may/AUDLDiscDetection-1/valid',
            'Analytics/Ultilitycs/test 08 may/AUDLDiscDetection-1/AUDLDiscDetection-1/valid')

# %% [markdown]
# # Trainig

# %%
dataset.location
# Out:
# '/home/julianzu/Analytics/Ultilitycs/test 08 may/AUDLDiscDetection-1'

# %%
# !yolo task = detect mode = train model = yolov8n.pt data = {dataset.location}/data.yaml epochs = 100 imgsz = 640

# %%
from ultralytics import YOLO

# %%
model = YOLO('/home/julianzu/Analytics/Ultilitycs/test 08 may/models/best.pt')

results = model.predict('/home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/Captura de pantalla 2024-05-12 213020.png', save = True)
print(results[0])
for box in results[0].boxes:
    print(box)
# Out:
# image 1/1 /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/Captura de pantalla 2024-05-12 213020.png: 352x640 1 Disc, 16 Players, 772.4ms
# Speed: 65.3ms preprocess, 772.4ms inference, 23.4ms postprocess per image at shape (1, 3, 352, 640)
# Results saved to runs/detect/predict14
# ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'Disc', 1: 'Player'}
# obb: None
# orig_img: array([[[111, 124, 111],
#         [111, 124, 111],
#         [111, 124, 111],
#         ...,
#         [117, 134, 124],
#         [116, 133, 123],
#         [117, 134, 123]],
#
#        [[111, 124, 111],
#         [111, 124, 111],
#         [111, 124, 111],
#         ...,
#         [117, 134, 124],
#         [116, 133, 122],
#         [115, 133, 122]],
#
#        [[111, 124, 111],
#         [111, 124, 111],
#         [111, 124, 111],
#         ...,
#         [117, 134, 123],
# ...

# %%
import cv2
def read_video(video_path):
    cap = cv2.VideoCapture(video_path)
    frames = []
    while True:
        ret, frame = cap.read()
        if not ret:
            break
        frames.append(frame)
    return frames

def save_video(output_video_frames, output_path):
    fourcc = cv2.VideoWriter_fourcc(*'XVID')
    out = cv2.VideoWriter(output_path, fourcc, 24, (output_video_frames[0].shape[1], output_video_frames[0].shape[0]))
    for frame in output_video_frames:
        out.write(frame)
    out.release()

# %%
#read video

video_frames = read_video('/home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4')

#save video

#save_video(video_frames, '/home/julianzu/Analytics/Ultilitycs/test 08 may/output_videos/drone trimmed.avi')

# %% [markdown]
# # Tracker

# %%
# !pip install supervision

# %%
from ultralytics import YOLO
import supervision as sv
import pickle
import os
import sys
import cv2
import numpy as np

# %%
#bbox utils:
def get_center_of_bbox(bbox):
    x1,y1,x2,y2 = bbox
    return int((x1+x2)/2), int((y1+y2)/2)

def get_bbox_width(bbox):
    return bbox[2]-bbox[0]

# %%
class Tracker:
    def __init__(self, model_path):
        self.model = YOLO(model_path)
        self.tracker = sv.ByteTrack()

    def detect_frames(self, frames):
        batch_size = 20
        detections = []
        for i in range(0,len(frames),batch_size):
            detections_batch = self.model.predict(frames[i:i+batch_size], conf = 0.1)
            detections += detections_batch
        return detections

    def get_object_tracks(self, frames, read_from_stub = False, stub_path = None):

        if read_from_stub and stub_path is not None and os.path.exists(stub_path):
            with open(stub_path,'rb') as f:
                tracks = pickle.load(f)
            return tracks

        detections = self.detect_frames(frames)

        tracks = {
            "players":[],
            "ball":[]
        }

        for frame_num, detection in enumerate(detections):
            cls_names = detection.names
            cls_names_inv = {v:k for k,v in cls_names.items()}
            

            #covert to supervision detection format
            detection_supervision = sv.Detections.from_ultralytics(detection)


            #track objects:
            detection_with_tracks = self.tracker.update_with_detections(detection_supervision)


            tracks["players"].append({})
            tracks["ball"].append({})

            
            for frame_detection in detection_with_tracks:
                bbox = frame_detection[0].tolist()
                cls_id = frame_detection[3]
                track_id = frame_detection[4]

                if cls_id == cls_names_inv['players']:
                    tracks["players"][frame_num][track_id] = {"bbox":bbox}



        if stub_path is not None:
            with open(stub_path,'wb') as f:
                pickle.dump(tracks,f)

        return tracks

    def draw_ellipse(self, frame, bbox, color, track_id = None):
        y2 = int(bbox[3])
        x_center, _ = get_center_of_bbox(bbox)
        width = get_bbox_width(bbox)

        cv2.ellipse(
            frame,
            center=(x_center,y2),
            axes=(int(width), int(0.35*width)),
            angle=0.0,
            startAngle=-45,
            endAngle=235,
            color = color,
            thickness=2,
            lineType=cv2.LINE_4
        )

        rectangle_width = 40
        rectangle_height=20
        x1_rect = x_center - rectangle_width//2
        x2_rect = x_center + rectangle_width//2
        y1_rect = (y2- rectangle_height//2) +15
        y2_rect = (y2+ rectangle_height//2) +15

        if track_id is not None:
            cv2.rectangle(frame,
                          (int(x1_rect),int(y1_rect) ),
                          (int(x2_rect),int(y2_rect)),
                          color,
                          cv2.FILLED)
            
            x1_text = x1_rect+12
            if track_id > 99:
                x1_text -=10
            
            cv2.putText(
                frame,
                f"{track_id}",
                (int(x1_text),int(y1_rect+15)),
                cv2.FONT_HERSHEY_SIMPLEX,
                0.6,
                (0,0,0),
                2
            )


        return frame






    def draw_annotations(self,video_frames, tracks):
        output_video_frames = []
        for frame_num, frame in enumerate(video_frames):
            frame = frame.copy()

            player_dict = tracks["players"][frame_num]
            ball_dict = tracks["ball"][frame_num]

            #draw Players

            for track_id, player in player_dict.items():
                frame = self.draw_ellipse(frame, players["bbox"],(0,0,255), track_id)


            output_video_frames.append(frame)

        return output_video_frames

# %%
class Tracker:
    def __init__(self, model_path):
        self.model = YOLO(model_path) 
        self.tracker = sv.ByteTrack()

    def add_position_to_tracks(self,tracks):
        for object, object_tracks in tracks.items():
            for frame_num, track in enumerate(object_tracks):
                for track_id, track_info in track.items():
                    bbox = track_info['bbox']
                    if object == 'ball':
                        position= get_center_of_bbox(bbox)
                    else:
                        position = get_foot_position(bbox)
                    tracks[object][frame_num][track_id]['position'] = position

    def detect_frames(self, frames):
        batch_size=20 
        detections = [] 
        for i in range(0,len(frames),batch_size):
            detections_batch = self.model.predict(frames[i:i+batch_size],conf=0.1)
            detections += detections_batch
        return detections

    def get_object_tracks(self, frames, read_from_stub=False, stub_path=None):
        
        if read_from_stub and stub_path is not None and os.path.exists(stub_path):
            with open(stub_path,'rb') as f:
                tracks = pickle.load(f)
            return tracks

        detections = self.detect_frames(frames)

        tracks={
            "players":[],
            "referees":[],
            "ball":[]
        }

        for frame_num, detection in enumerate(detections):
            cls_names = detection.names
            cls_names_inv = {v:k for k,v in cls_names.items()}

            # Covert to supervision Detection format
            detection_supervision = sv.Detections.from_ultralytics(detection)


            # Track Objects
            detection_with_tracks = self.tracker.update_with_detections(detection_supervision)

            tracks["players"].append({})
            tracks["referees"].append({})
            tracks["ball"].append({})

            for frame_detection in detection_with_tracks:
                bbox = frame_detection[0].tolist()
                cls_id = frame_detection[3]
                track_id = frame_detection[4]

                if cls_id == cls_names_inv['player']:
                    tracks["players"][frame_num][track_id] = {"bbox":bbox}
                
                if cls_id == cls_names_inv['referee']:
                    tracks["referees"][frame_num][track_id] = {"bbox":bbox}
            
            for frame_detection in detection_supervision:
                bbox = frame_detection[0].tolist()
                cls_id = frame_detection[3]

                if cls_id == cls_names_inv['ball']:
                    tracks["ball"][frame_num][1] = {"bbox":bbox}

        if stub_path is not None:
            with open(stub_path,'wb') as f:
                pickle.dump(tracks,f)

        return tracks
    
    def draw_ellipse(self,frame,bbox,color,track_id=None):
        y2 = int(bbox[3])
        x_center, _ = get_center_of_bbox(bbox)
        width = get_bbox_width(bbox)

        cv2.ellipse(
            frame,
            center=(x_center,y2),
            axes=(int(width), int(0.35*width)),
            angle=0.0,
            startAngle=-45,
            endAngle=235,
            color = color,
            thickness=2,
            lineType=cv2.LINE_4
        )

        rectangle_width = 40
        rectangle_height=20
        x1_rect = x_center - rectangle_width//2
        x2_rect = x_center + rectangle_width//2
        y1_rect = (y2- rectangle_height//2) +15
        y2_rect = (y2+ rectangle_height//2) +15

        if track_id is not None:
            cv2.rectangle(frame,
                          (int(x1_rect),int(y1_rect) ),
                          (int(x2_rect),int(y2_rect)),
                          color,
                          cv2.FILLED)
            
            x1_text = x1_rect+12
            if track_id > 99:
                x1_text -=10
            
            cv2.putText(
                frame,
                f"{track_id}",
                (int(x1_text),int(y1_rect+15)),
                cv2.FONT_HERSHEY_SIMPLEX,
                0.6,
                (0,0,0),
                2
            )

        return frame

    def draw_traingle(self,frame,bbox,color):
        y= int(bbox[1])
        x,_ = get_center_of_bbox(bbox)

        triangle_points = np.array([
            [x,y],
            [x-10,y-20],
            [x+10,y-20],
        ])
        cv2.drawContours(frame, [triangle_points],0,color, cv2.FILLED)
        cv2.drawContours(frame, [triangle_points],0,(0,0,0), 2)

        return frame


    def draw_annotations(self,video_frames):
        output_video_frames= []
        for frame_num, frame in enumerate(video_frames):
            frame = frame.copy()

            player_dict = tracks["players"][frame_num]
            ball_dict = tracks["ball"][frame_num]
            referee_dict = tracks["referees"][frame_num]

            # Draw Players
            for track_id, player in player_dict.items():
                color = player.get("team_color",(0,0,255))
                frame = self.draw_ellipse(frame, player["bbox"],color, track_id)

                if player.get('has_ball',False):
                    frame = self.draw_traingle(frame, player["bbox"],(0,0,255))

            # Draw Referee
            for _, referee in referee_dict.items():
                frame = self.draw_ellipse(frame, referee["bbox"],(0,255,255))
            
            # Draw ball 
            for track_id, ball in ball_dict.items():
                frame = self.draw_traingle(frame, ball["bbox"],(0,255,0))




            output_video_frames.append(frame)

        return output_video_frames

# %% [markdown]
# ## for futbol

# %%
class Tracker:
    def __init__(self, model_path):
        self.model = YOLO(model_path) 
        self.tracker = sv.ByteTrack()

    def detect_frames(self, frames):
        batch_size=20 
        detections = [] 
        for i in range(0,len(frames),batch_size):
            detections_batch = self.model.predict(frames[i:i+batch_size],conf=0.1)
            detections += detections_batch

        return detections

    def get_object_tracks(self, frames, read_from_stub = False, stub_path =None):

        if read_from_stub and stub_path is not None and os.path.exists(stub_path):
            with open(stub_path,'rb') as f:
                tracks = pickle.load(f)
            return tracks

        detections = self.detect_frames(frames)

        tracks={"players":[], "referees":[], "ball":[]}



        for frame_num, detection in enumerate(detections):
            cls_names = detection.names
            cls_names_inv = {v:k for k,v in cls_names.items()}

            #convert to supervision Detection format
            detection_supervision = sv.Detections.from_ultralytics(detection)

            #track objects
            detection_with_tracks = self.tracker.update_with_detections(detection_supervision)

            tracks["players"].append({})
            tracks["referees"].append({})
            tracks["ball"].append({})

            for frame_detection in detection_with_tracks:
                bbox = frame_detection[0].tolist()
                cls_id = frame_detection[3]
                track_id = frame_detection[4]

                if cls_id == cls_names_inv['player']:
                    tracks["players"][frame_num][track_id] = {"bbox":bbox}
                
            
            for frame_detection in detection_supervision:
                bbox = frame_detection[0].tolist()
                cls_id = frame_detection[3]

                if cls_id == cls_names_inv['ball']:
                    tracks["ball"][frame_num][1] = {"bbox":bbox}

            if stub_path is not None:
                with open(stub_path,'wb') as f:
                    pickle.dump(tracks,f)
                

            return tracks

    def draw_ellipse(self, frame, bbox, color, track_id):
        y2 = int(bbox[3])
        x_center, _ = get_center_of_bbox(bbox)
        width = get_bbox_width(bbox)

        cv2.ellipse(
            frame,
            center=(x_center,y2),
            axes=(int(width), int(0.35*width)),
            angle=0.0,
            startAngle=-45,
            endAngle=235,
            color = color,
            thickness=2,
            lineType=cv2.LINE_4
        )

        return frame    

    def draw_annotations(self,video_frames, tracks):
        output_video_frames= []
        for frame_num, frame in enumerate(video_frames):
            frame = frame.copy()

            player_dict = tracks["players"][frame_num]
            ball_dict = tracks["ball"][frame_num]
            referee_dict = tracks["referees"][frame_num]

            # Draw Players
            for track_id, player in player_dict.items():
                frame = self.draw_ellipse(frame, player["bbox"],(0,0,255), track_id)






            output_video_frames.append(frame)

        return output_video_frames

# %%
tracks["players"][0]
# Out:
# {80: {'bbox': [71.22286224365234,
#    206.84564208984375,
#    84.4128646850586,
#    230.47886657714844]},
#  81: {'bbox': [699.99365234375,
#    274.36480712890625,
#    712.4686279296875,
#    305.104736328125]},
#  82: {'bbox': [721.2916870117188,
#    243.30067443847656,
#    735.8333740234375,
#    277.218505859375]},
#  83: {'bbox': [616.7117309570312,
#    169.70938110351562,
#    624.7066650390625,
#    190.66384887695312]},
#  84: {'bbox': [786.7869873046875,
#    327.93927001953125,
#    805.0064086914062,
#    355.28533935546875]},
#  85: {'bbox': [798.9725341796875,
#    304.31109619140625,
#    820.8871459960938,
#    334.2831115722656]},
#  86: {'bbox': [378.9238586425781,
#    300.8511657714844,
#    395.55560302734375,
#    345.3163146972656]},
#  87: {'bbox': [452.30914306640625,
#    212.23663330078125,
#    464.51983642578125,
#    233.7908477783203]},
#  88: {'bbox': [729.4370727539062,
#    215.29917907714844,
#    740.610595703125,
#    235.4311065673828]},
# ...

# %%
# read video
video_frames = read_video('/home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4')

#initialize tracker
tracker = Tracker('/home/julianzu/Analytics/Ultilitycs/test 08 may/models/bestfutbol.pt')
tracks = tracker.get_object_tracks(video_frames, read_from_stub = True, stub_path = 'stubs/track_stubs.pkl' )


#draw output
##draw object tracks
output_video_frames = tracker.draw_annotations(video_frames, tracks)

#save video
save_video(output_video_frames, '/home/julianzu/Analytics/Ultilitycs/test 08 may/output_videos/drone trimmed.avi')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[35], line 11
#       6 tracks = tracker.get_object_tracks(video_frames, read_from_stub = True, stub_path = 'stubs/track_stubs.pkl' )
#       9 #draw output
#      10 ##draw object tracks
# ---> 11 output_video_frames = tracker.draw_annotations(video_frames, tracks)
#      13 #save video
#      14 save_video(output_video_frames, '/home/julianzu/Analytics/Ultilitycs/test 08 may/output_videos/drone trimmed.avi')
#
# Cell In[34], line 89, in Tracker.draw_annotations(self, video_frames, tracks)
#      86 for frame_num, frame in enumerate(video_frames):
#      87     frame = frame.copy()
# ---> 89     player_dict = tracks["players"][frame_num]
#      90     ball_dict = tracks["ball"][frame_num]
#      91     referee_dict = tracks["referees"][frame_num]
#
# IndexError: list index out of range

# %% [markdown]
# ## rest

# %%
#read video

video_frames = read_video('/home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4')

#initialize tracker:
tracker = Tracker('/home/julianzu/Analytics/Ultilitycs/test 08 may/models/bestfutbol.pt')
tracks = tracker.get_object_tracks(video_frames, read_from_stub = True, stub_path = 'stubs/track_stubs.pkl' )



#draw output
##draw object tracks
output_video_frames = tracker.draw_annotations(video_frames)

#save video

save_video(output_video_frames, '/home/julianzu/Analytics/Ultilitycs/test 08 may/output_videos/drone trimmed.avi')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[114], line 13
#       7 tracks = tracker.get_object_tracks(video_frames, read_from_stub = True, stub_path = 'stubs/track_stubs.pkl' )
#      11 #draw output
#      12 ##draw object tracks
# ---> 13 output_video_frames = tracker.draw_annotations(video_frames)
#      15 #save video
#      17 save_video(output_video_frames, '/home/julianzu/Analytics/Ultilitycs/test 08 may/output_videos/drone trimmed.avi')
#
# Cell In[113], line 146, in Tracker.draw_annotations(self, video_frames)
#     143 for frame_num, frame in enumerate(video_frames):
#     144     frame = frame.copy()
# --> 146     player_dict = tracks["players"][frame_num]
#     147     ball_dict = tracks["ball"][frame_num]
#     148     referee_dict = tracks["referees"][frame_num]
#
# KeyError: 'players'

# %% [markdown]
# # Color Assignament
