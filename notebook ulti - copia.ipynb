# %%
from ultralytics import YOLO

model = YOLO('yolov8n')

results = model.predict('/home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4', save = True)
print(results[0])
for box in results[0].boxes:
    print(box)
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (1/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 2 persons, 1 bus, 1441.7ms
# video 1/1 (2/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 2 persons, 1 bus, 205.2ms
# video 1/1 (3/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 2 persons, 1 bus, 134.3ms
# video 1/1 (4/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 2 persons, 1 bus, 151.7ms
# video 1/1 (5/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 3 persons, 1 bus, 1 truck, 190.5ms
# video 1/1 (6/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 3 persons, 1 bus, 1 truck, 178.8ms
# video 1/1 (7/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 4 persons, 1 bus, 162.9ms
# video 1/1 (8/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 5 persons, 1 bus, 179.8ms
# video 1/1 (9/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 3 persons, 1 bus, 203.7ms
# video 1/1 (10/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 4 persons, 1 bus, 284.1ms
# video 1/1 (11/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 5 persons, 1 bus, 259.9ms
# video 1/1 (12/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 5 persons, 1 bus, 225.5ms
# video 1/1 (13/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 4 persons, 544.7ms
# video 1/1 (14/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 6 persons, 313.0ms
# video 1/1 (15/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 5 persons, 230.4ms
# video 1/1 (16/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 4 persons, 130.8ms
# video 1/1 (17/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 5 persons, 1 truck, 131.9ms
# video 1/1 (18/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 5 persons, 1 truck, 123.9ms
# video 1/1 (19/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 6 persons, 1 truck, 156.8ms
# video 1/1 (20/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 6 persons, 149.9ms
# video 1/1 (21/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 4 persons, 1 truck, 148.9ms
# video 1/1 (22/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 7 persons, 1 truck, 160.1ms
# video 1/1 (23/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 6 persons, 1 truck, 133.2ms
# video 1/1 (24/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 7 persons, 1 truck, 122.7ms
# video 1/1 (25/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 8 persons, 1 bus, 151.4ms
# video 1/1 (26/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 6 persons, 1 bus, 127.5ms
# video 1/1 (27/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 5 persons, 1 bus, 125.0ms
# video 1/1 (28/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 5 persons, 1 bus, 115.9ms
# video 1/1 (29/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 8 persons, 1 bus, 119.3ms
# video 1/1 (30/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 7 persons, 1 bus, 137.2ms
# video 1/1 (31/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 5 persons, 1 bus, 136.2ms
# video 1/1 (32/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 2 persons, 1 bus, 144.0ms
# video 1/1 (33/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 3 persons, 1 bus, 111.9ms
# video 1/1 (34/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 4 persons, 1 bus, 152.7ms
# video 1/1 (35/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 2 persons, 1 bus, 156.3ms
# video 1/1 (36/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 4 persons, 1 bus, 125.7ms
# video 1/1 (37/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 3 persons, 1 bus, 127.1ms
# video 1/1 (38/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 2 persons, 1 bus, 141.2ms
# video 1/1 (39/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 2 persons, 1 bus, 138.6ms
# video 1/1 (40/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 2 persons, 1 bus, 120.9ms
# video 1/1 (41/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 3 persons, 1 bus, 124.2ms
# video 1/1 (42/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 3 persons, 1 bus, 146.2ms
# video 1/1 (43/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 3 persons, 1 bus, 122.9ms
# video 1/1 (44/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 2 persons, 1 bus, 142.2ms
# video 1/1 (45/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 2 persons, 1 bus, 121.3ms
# video 1/1 (46/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 2 persons, 1 bus, 205.9ms
# video 1/1 (47/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 5 persons, 1 bus, 176.1ms
# video 1/1 (48/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 4 persons, 1 bus, 131.2ms
# video 1/1 (49/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 6 persons, 127.0ms
# video 1/1 (50/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 5 persons, 111.8ms
# video 1/1 (51/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 5 persons, 128.5ms
# video 1/1 (52/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 6 persons, 1 traffic light, 110.8ms
# video 1/1 (53/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 7 persons, 1 traffic light, 133.8ms
# video 1/1 (54/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 5 persons, 1 traffic light, 150.3ms
# video 1/1 (55/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 5 persons, 1 truck, 1 traffic light, 176.4ms
# video 1/1 (56/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 5 persons, 1 truck, 1 traffic light, 149.1ms
# video 1/1 (57/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 4 persons, 1 truck, 1 traffic light, 190.6ms
# video 1/1 (58/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 5 persons, 1 truck, 1 traffic light, 123.6ms
# video 1/1 (59/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 7 persons, 1 traffic light, 129.4ms
# video 1/1 (60/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 8 persons, 1 truck, 1 traffic light, 126.3ms
# video 1/1 (61/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 4 persons, 1 traffic light, 156.7ms
# video 1/1 (62/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 5 persons, 1 traffic light, 498.5ms
# video 1/1 (63/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 7 persons, 1 truck, 1 traffic light, 134.5ms
# video 1/1 (64/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 8 persons, 1 traffic light, 173.9ms
# video 1/1 (65/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 6 persons, 1 traffic light, 384.4ms
# video 1/1 (66/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 7 persons, 1 traffic light, 124.2ms
# video 1/1 (67/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 7 persons, 1 traffic light, 142.7ms
# video 1/1 (68/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 5 persons, 1 traffic light, 194.5ms
# video 1/1 (69/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 6 persons, 1 traffic light, 209.3ms
# video 1/1 (70/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 5 persons, 1 traffic light, 208.2ms
# video 1/1 (71/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 7 persons, 1 traffic light, 165.0ms
# video 1/1 (72/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 6 persons, 1 traffic light, 144.5ms
# video 1/1 (73/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 9 persons, 1 traffic light, 127.2ms
# video 1/1 (74/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 8 persons, 1 traffic light, 149.2ms
# video 1/1 (75/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 7 persons, 1 traffic light, 153.7ms
# video 1/1 (76/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 8 persons, 1 traffic light, 151.0ms
# video 1/1 (77/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 8 persons, 1 traffic light, 157.0ms
# video 1/1 (78/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 8 persons, 1 traffic light, 128.5ms
# video 1/1 (79/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 9 persons, 1 traffic light, 151.6ms
# video 1/1 (80/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 8 persons, 1 traffic light, 145.0ms
# video 1/1 (81/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 7 persons, 1 traffic light, 123.0ms
# video 1/1 (82/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 6 persons, 1 traffic light, 160.9ms
# video 1/1 (83/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 7 persons, 1 traffic light, 123.5ms
# video 1/1 (84/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 6 persons, 1 bus, 1 traffic light, 133.1ms
# video 1/1 (85/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 7 persons, 1 bus, 1 traffic light, 129.6ms
# video 1/1 (86/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 7 persons, 1 bus, 2 traffic lights, 145.4ms
# video 1/1 (87/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 9 persons, 1 bus, 2 traffic lights, 150.6ms
# video 1/1 (88/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 11 persons, 1 bus, 151.6ms
# video 1/1 (89/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 9 persons, 1 bus, 131.7ms
# video 1/1 (90/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 9 persons, 1 bus, 151.1ms
# video 1/1 (91/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 6 persons, 1 bus, 199.5ms
# video 1/1 (92/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 6 persons, 1 bus, 182.4ms
# video 1/1 (93/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 5 persons, 1 bus, 160.6ms
# video 1/1 (94/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 5 persons, 1 bus, 146.4ms
# video 1/1 (95/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 8 persons, 1 bus, 159.5ms
# video 1/1 (96/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 4 persons, 1 bus, 148.7ms
# video 1/1 (97/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 4 persons, 142.0ms
# video 1/1 (98/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 5 persons, 153.0ms
# video 1/1 (99/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 4 persons, 129.7ms
# video 1/1 (100/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 4 persons, 165.6ms
# video 1/1 (101/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 5 persons, 136.3ms
# video 1/1 (102/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 3 persons, 161.5ms
# video 1/1 (103/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 4 persons, 1 bus, 151.8ms
# video 1/1 (104/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 9 persons, 1 bus, 177.7ms
# video 1/1 (105/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 9 persons, 130.1ms
# video 1/1 (106/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 7 persons, 157.5ms
# video 1/1 (107/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 5 persons, 124.0ms
# video 1/1 (108/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 5 persons, 139.4ms
# video 1/1 (109/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 3 persons, 131.2ms
# video 1/1 (110/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 5 persons, 131.2ms
# video 1/1 (111/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 6 persons, 126.1ms
# video 1/1 (112/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 7 persons, 132.3ms
# video 1/1 (113/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 6 persons, 125.9ms
# video 1/1 (114/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 5 persons, 121.5ms
# video 1/1 (115/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 6 persons, 127.9ms
# video 1/1 (116/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 7 persons, 125.8ms
# video 1/1 (117/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 8 persons, 139.9ms
# video 1/1 (118/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 11 persons, 232.5ms
# video 1/1 (119/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 14 persons, 136.0ms
# video 1/1 (120/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 12 persons, 122.3ms
# video 1/1 (121/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 6 persons, 155.1ms
# video 1/1 (122/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 6 persons, 132.8ms
# video 1/1 (123/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 6 persons, 150.2ms
# video 1/1 (124/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 6 persons, 173.3ms
# video 1/1 (125/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 6 persons, 172.5ms
# video 1/1 (126/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 6 persons, 152.2ms
# video 1/1 (127/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 8 persons, 243.1ms
# video 1/1 (128/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 8 persons, 145.7ms
# video 1/1 (129/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 7 persons, 136.0ms
# video 1/1 (130/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 8 persons, 158.9ms
# video 1/1 (131/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 7 persons, 144.0ms
# video 1/1 (132/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 8 persons, 132.2ms
# video 1/1 (133/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 10 persons, 156.5ms
# video 1/1 (134/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 10 persons, 144.5ms
# video 1/1 (135/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 12 persons, 190.8ms
# video 1/1 (136/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 10 persons, 234.3ms
# video 1/1 (137/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 10 persons, 336.5ms
# video 1/1 (138/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 9 persons, 341.3ms
# video 1/1 (139/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 11 persons, 218.5ms
# video 1/1 (140/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 10 persons, 235.4ms
# video 1/1 (141/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 11 persons, 242.1ms
# video 1/1 (142/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 12 persons, 244.2ms
# video 1/1 (143/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 10 persons, 144.0ms
# video 1/1 (144/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 13 persons, 155.0ms
# video 1/1 (145/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 12 persons, 1 bus, 158.9ms
# video 1/1 (146/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 11 persons, 1 bus, 202.4ms
# video 1/1 (147/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 12 persons, 151.7ms
# video 1/1 (148/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 11 persons, 1 bus, 149.4ms
# video 1/1 (149/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 7 persons, 1 bus, 275.9ms
# video 1/1 (150/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 8 persons, 1 bus, 258.9ms
# video 1/1 (151/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 8 persons, 1 bus, 242.1ms
# video 1/1 (152/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 8 persons, 1 bus, 207.3ms
# video 1/1 (153/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 9 persons, 1 bus, 161.2ms
# video 1/1 (154/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 9 persons, 1 bus, 160.8ms
# video 1/1 (155/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 8 persons, 1 bus, 188.7ms
# video 1/1 (156/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 6 persons, 1 bus, 155.5ms
# video 1/1 (157/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 7 persons, 1 bus, 179.9ms
# video 1/1 (158/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 9 persons, 1 bus, 166.9ms
# video 1/1 (159/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 8 persons, 1 bus, 209.5ms
# video 1/1 (160/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 11 persons, 1 bus, 158.6ms
# video 1/1 (161/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 8 persons, 1 bus, 168.4ms
# video 1/1 (162/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 7 persons, 158.8ms
# video 1/1 (163/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 6 persons, 148.4ms
# video 1/1 (164/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 8 persons, 239.8ms
# video 1/1 (165/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 9 persons, 227.1ms
# video 1/1 (166/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 11 persons, 1 bus, 159.9ms
# video 1/1 (167/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 9 persons, 140.3ms
# video 1/1 (168/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 8 persons, 162.8ms
# video 1/1 (169/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 5 persons, 136.4ms
# video 1/1 (170/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 5 persons, 139.7ms
# video 1/1 (171/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 3 persons, 183.3ms
# video 1/1 (172/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 3 persons, 136.3ms
# video 1/1 (173/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 5 persons, 158.1ms
# video 1/1 (174/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 8 persons, 148.2ms
# video 1/1 (175/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 4 persons, 1 traffic light, 150.1ms
# video 1/1 (176/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 3 persons, 1 traffic light, 126.0ms
# video 1/1 (177/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 3 persons, 1 traffic light, 309.0ms
# video 1/1 (178/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 2 persons, 1 traffic light, 130.6ms
# video 1/1 (179/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 5 persons, 245.1ms
# video 1/1 (180/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 7 persons, 498.5ms
# video 1/1 (181/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 7 persons, 1 traffic light, 321.6ms
# video 1/1 (182/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 5 persons, 1 traffic light, 148.6ms
# video 1/1 (183/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 8 persons, 1 traffic light, 127.3ms
# video 1/1 (184/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 11 persons, 126.4ms
# video 1/1 (185/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 9 persons, 141.0ms
# video 1/1 (186/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 7 persons, 143.2ms
# video 1/1 (187/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 10 persons, 145.9ms
# video 1/1 (188/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 7 persons, 112.8ms
# video 1/1 (189/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 6 persons, 134.9ms
# video 1/1 (190/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 8 persons, 134.2ms
# video 1/1 (191/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 8 persons, 141.3ms
# video 1/1 (192/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 9 persons, 164.4ms
# video 1/1 (193/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 9 persons, 125.1ms
# video 1/1 (194/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 8 persons, 120.1ms
# video 1/1 (195/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 12 persons, 127.6ms
# video 1/1 (196/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 14 persons, 140.1ms
# video 1/1 (197/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 10 persons, 130.9ms
# video 1/1 (198/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 12 persons, 142.5ms
# video 1/1 (199/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 13 persons, 136.9ms
# video 1/1 (200/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 13 persons, 124.2ms
# video 1/1 (201/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 13 persons, 136.2ms
# video 1/1 (202/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 13 persons, 154.6ms
# video 1/1 (203/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 13 persons, 145.2ms
# video 1/1 (204/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 11 persons, 136.6ms
# video 1/1 (205/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 12 persons, 134.9ms
# video 1/1 (206/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 15 persons, 138.1ms
# video 1/1 (207/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 15 persons, 133.1ms
# video 1/1 (208/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 15 persons, 119.8ms
# video 1/1 (209/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 14 persons, 142.5ms
# video 1/1 (210/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 16 persons, 122.9ms
# video 1/1 (211/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 11 persons, 150.7ms
# video 1/1 (212/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 10 persons, 146.8ms
# video 1/1 (213/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 8 persons, 126.0ms
# video 1/1 (214/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 11 persons, 135.5ms
# video 1/1 (215/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 13 persons, 143.6ms
# video 1/1 (216/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 14 persons, 141.2ms
# video 1/1 (217/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 16 persons, 128.0ms
# video 1/1 (218/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 18 persons, 141.2ms
# video 1/1 (219/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 18 persons, 152.1ms
# video 1/1 (220/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 20 persons, 128.2ms
# video 1/1 (221/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 16 persons, 131.5ms
# video 1/1 (222/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 14 persons, 131.2ms
# video 1/1 (223/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 12 persons, 135.4ms
# video 1/1 (224/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 13 persons, 149.6ms
# video 1/1 (225/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 13 persons, 145.8ms
# video 1/1 (226/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 15 persons, 153.1ms
# video 1/1 (227/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 18 persons, 153.8ms
# video 1/1 (228/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 16 persons, 136.3ms
# Speed: 3.9ms preprocess, 169.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/predict11
# ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[ 84,  89,  89],
#         [ 97, 102, 102],
#         [110, 115, 115],
#         ...,
#         [ 55,  45,  47],
#         [ 55,  45,  47],
#         [ 49,  39,  41]],
#
#        [[107, 112, 112],
#         [109, 114, 114],
#         [103, 108, 108],
#         ...,
#         [ 61,  51,  53],
#         [ 61,  51,  53],
#         [ 55,  45,  47]],
#
#        [[112, 117, 117],
#         [103, 108, 108],
#         [ 93,  98,  98],
#         ...,
#         [ 61,  51,  53],
#         [ 61,  51,  53],
#         [ 55,  45,  47]],
#
#        ...,
#
#        [[ 86, 100,  87],
#         [ 86, 100,  87],
#         [ 86, 100,  87],
#         ...,
#         [ 54,  37,  58],
#         [ 45,  26,  52],
#         [ 42,  23,  49]],
#
#        [[ 86, 100,  87],
#         [ 86, 100,  87],
#         [ 86, 100,  87],
#         ...,
#         [ 48,  31,  52],
#         [ 46,  27,  53],
#         [ 48,  29,  55]],
#
#        [[ 86, 100,  87],
#         [ 86, 100,  87],
#         [ 86, 100,  87],
#         ...,
#         [ 42,  25,  46],
#         [ 60,  41,  67],
#         [ 58,  39,  65]]], dtype=uint8)
# orig_shape: (480, 848)
# path: '/home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4'
# probs: None
# save_dir: 'runs/detect/predict11'
# speed: {'preprocess': 29.996633529663086, 'inference': 1441.7190551757812, 'postprocess': 29.38246726989746}
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.])
# conf: tensor([0.3582])
# data: tensor([[ 72.0286, 208.0255,  83.5129, 229.3109,   0.3582,   0.0000]])
# id: None
# is_track: False
# orig_shape: (480, 848)
# shape: torch.Size([1, 6])
# xywh: tensor([[ 77.7708, 218.6682,  11.4844,  21.2855]])
# xywhn: tensor([[0.0917, 0.4556, 0.0135, 0.0443]])
# xyxy: tensor([[ 72.0286, 208.0255,  83.5129, 229.3109]])
# xyxyn: tensor([[0.0849, 0.4334, 0.0985, 0.4777]])
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([5.])
# conf: tensor([0.3326])
# data: tensor([[3.9036e-02, 5.8192e+01, 6.0711e+01, 2.0700e+02, 3.3255e-01, 5.0000e+00]])
# id: None
# is_track: False
# orig_shape: (480, 848)
# shape: torch.Size([1, 6])
# xywh: tensor([[ 30.3749, 132.5955,  60.6717, 148.8063]])
# xywhn: tensor([[0.0358, 0.2762, 0.0715, 0.3100]])
# xyxy: tensor([[3.9036e-02, 5.8192e+01, 6.0711e+01, 2.0700e+02]])
# xyxyn: tensor([[4.6033e-05, 1.2123e-01, 7.1593e-02, 4.3125e-01]])
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.])
# conf: tensor([0.2793])
# data: tensor([[3.8047e+02, 3.0291e+02, 3.9422e+02, 3.4411e+02, 2.7932e-01, 0.0000e+00]])
# id: None
# is_track: False
# orig_shape: (480, 848)
# shape: torch.Size([1, 6])
# xywh: tensor([[387.3414, 323.5104,  13.7504,  41.2057]])
# xywhn: tensor([[0.4568, 0.6740, 0.0162, 0.0858]])
# xyxy: tensor([[380.4662, 302.9075, 394.2166, 344.1132]])
# xyxyn: tensor([[0.4487, 0.6311, 0.4649, 0.7169]])

# %%
print(results[0])
for box in results[0].boxes:
    print(box)
# Out:
# ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[ 84,  89,  89],
#         [ 97, 102, 102],
#         [110, 115, 115],
#         ...,
#         [ 55,  45,  47],
#         [ 55,  45,  47],
#         [ 49,  39,  41]],
#
#        [[107, 112, 112],
#         [109, 114, 114],
#         [103, 108, 108],
#         ...,
#         [ 61,  51,  53],
#         [ 61,  51,  53],
#         [ 55,  45,  47]],
#
#        [[112, 117, 117],
#         [103, 108, 108],
#         [ 93,  98,  98],
#         ...,
#         [ 61,  51,  53],
#         [ 61,  51,  53],
#         [ 55,  45,  47]],
#
#        ...,
#
#        [[ 86, 100,  87],
#         [ 86, 100,  87],
#         [ 86, 100,  87],
#         ...,
#         [ 54,  37,  58],
#         [ 45,  26,  52],
#         [ 42,  23,  49]],
#
#        [[ 86, 100,  87],
#         [ 86, 100,  87],
#         [ 86, 100,  87],
#         ...,
#         [ 48,  31,  52],
#         [ 46,  27,  53],
#         [ 48,  29,  55]],
#
#        [[ 86, 100,  87],
#         [ 86, 100,  87],
#         [ 86, 100,  87],
#         ...,
#         [ 42,  25,  46],
#         [ 60,  41,  67],
#         [ 58,  39,  65]]], dtype=uint8)
# orig_shape: (480, 848)
# path: '/home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4'
# probs: None
# save_dir: 'runs/detect/predict11'
# speed: {'preprocess': 29.996633529663086, 'inference': 1441.7190551757812, 'postprocess': 29.38246726989746}
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.])
# conf: tensor([0.3582])
# data: tensor([[ 72.0286, 208.0255,  83.5129, 229.3109,   0.3582,   0.0000]])
# id: None
# is_track: False
# orig_shape: (480, 848)
# shape: torch.Size([1, 6])
# xywh: tensor([[ 77.7708, 218.6682,  11.4844,  21.2855]])
# xywhn: tensor([[0.0917, 0.4556, 0.0135, 0.0443]])
# xyxy: tensor([[ 72.0286, 208.0255,  83.5129, 229.3109]])
# xyxyn: tensor([[0.0849, 0.4334, 0.0985, 0.4777]])
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([5.])
# conf: tensor([0.3326])
# data: tensor([[3.9036e-02, 5.8192e+01, 6.0711e+01, 2.0700e+02, 3.3255e-01, 5.0000e+00]])
# id: None
# is_track: False
# orig_shape: (480, 848)
# shape: torch.Size([1, 6])
# xywh: tensor([[ 30.3749, 132.5955,  60.6717, 148.8063]])
# xywhn: tensor([[0.0358, 0.2762, 0.0715, 0.3100]])
# xyxy: tensor([[3.9036e-02, 5.8192e+01, 6.0711e+01, 2.0700e+02]])
# xyxyn: tensor([[4.6033e-05, 1.2123e-01, 7.1593e-02, 4.3125e-01]])
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.])
# conf: tensor([0.2793])
# data: tensor([[3.8047e+02, 3.0291e+02, 3.9422e+02, 3.4411e+02, 2.7932e-01, 0.0000e+00]])
# id: None
# is_track: False
# orig_shape: (480, 848)
# shape: torch.Size([1, 6])
# xywh: tensor([[387.3414, 323.5104,  13.7504,  41.2057]])
# xywhn: tensor([[0.4568, 0.6740, 0.0162, 0.0858]])
# xyxy: tensor([[380.4662, 302.9075, 394.2166, 344.1132]])
# xyxyn: tensor([[0.4487, 0.6311, 0.4649, 0.7169]])

# %%
import random
import matplotlib.pyplot as plt

# Cargar el modelo
model = YOLO('yolov8m', task='segm')  # Asegúrate de especificar el task adecuado si es necesario

# Realizar la predicción
results = model.predict('input_videos/drone trimmed.mp4', save = True)

# Asegurarse de que hay detecciones con máscaras
if 'masks' in results.attr and len(results.masks) > 0:
    # Elegir una máscara aleatoria
    random_index = random.randint(0, len(results.masks) - 1)
    mask = results.masks[random_index]

    # Visualizar la máscara
    plt.imshow(mask, cmap='gray')
    plt.title('Random Object Mask')
    plt.axis('off')
    plt.show()
else:
    print("No masks found in the results.")
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (1/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 13 persons, 797.5ms
# video 1/1 (2/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 13 persons, 777.1ms
# video 1/1 (3/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 16 persons, 708.6ms
# video 1/1 (4/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 15 persons, 726.3ms
# video 1/1 (5/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 13 persons, 718.8ms
# video 1/1 (6/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 14 persons, 704.5ms
# video 1/1 (7/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 14 persons, 680.1ms
# video 1/1 (8/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 14 persons, 668.4ms
# video 1/1 (9/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 15 persons, 696.7ms
# video 1/1 (10/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 17 persons, 641.2ms
# video 1/1 (11/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 17 persons, 695.0ms
# video 1/1 (12/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 15 persons, 657.0ms
# video 1/1 (13/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 14 persons, 1074.8ms
# video 1/1 (14/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 14 persons, 911.9ms
# video 1/1 (15/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 14 persons, 657.5ms
# video 1/1 (16/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 12 persons, 674.9ms
# video 1/1 (17/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 10 persons, 689.5ms
# video 1/1 (18/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 12 persons, 705.6ms
# video 1/1 (19/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 12 persons, 645.2ms
# video 1/1 (20/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 11 persons, 677.0ms
# video 1/1 (21/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 12 persons, 669.3ms
# video 1/1 (22/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 12 persons, 645.1ms
# video 1/1 (23/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 11 persons, 726.2ms
# video 1/1 (24/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 13 persons, 675.5ms
# video 1/1 (25/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 15 persons, 685.2ms
# video 1/1 (26/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 14 persons, 666.9ms
# video 1/1 (27/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 14 persons, 650.4ms
# video 1/1 (28/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 15 persons, 662.1ms
# video 1/1 (29/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 13 persons, 704.8ms
# video 1/1 (30/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 14 persons, 700.1ms
# video 1/1 (31/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 14 persons, 687.3ms
# video 1/1 (32/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 12 persons, 689.3ms
# video 1/1 (33/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 14 persons, 799.0ms
# video 1/1 (34/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 13 persons, 834.3ms
# video 1/1 (35/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 13 persons, 707.3ms
# video 1/1 (36/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 14 persons, 720.6ms
# video 1/1 (37/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 17 persons, 653.9ms
# video 1/1 (38/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 18 persons, 711.0ms
# video 1/1 (39/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 17 persons, 1026.3ms
# video 1/1 (40/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 17 persons, 744.7ms
# video 1/1 (41/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 14 persons, 754.9ms
# video 1/1 (42/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 16 persons, 734.3ms
# video 1/1 (43/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 16 persons, 690.9ms
# video 1/1 (44/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 17 persons, 700.8ms
# video 1/1 (45/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 17 persons, 727.1ms
# video 1/1 (46/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 17 persons, 828.9ms
# video 1/1 (47/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 17 persons, 1237.1ms
# video 1/1 (48/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 14 persons, 878.2ms
# video 1/1 (49/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 14 persons, 847.4ms
# video 1/1 (50/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 18 persons, 713.6ms
# video 1/1 (51/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 18 persons, 704.7ms
# video 1/1 (52/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 16 persons, 896.2ms
# video 1/1 (53/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 17 persons, 755.9ms
# video 1/1 (54/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 17 persons, 976.8ms
# video 1/1 (55/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 16 persons, 1371.5ms
# video 1/1 (56/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 15 persons, 1403.1ms
# video 1/1 (57/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 17 persons, 1338.8ms
# video 1/1 (58/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 18 persons, 1163.9ms
# video 1/1 (59/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 18 persons, 1017.2ms
# video 1/1 (60/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 18 persons, 761.0ms
# video 1/1 (61/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 16 persons, 1105.8ms
# video 1/1 (62/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 16 persons, 847.2ms
# video 1/1 (63/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 15 persons, 1105.0ms
# video 1/1 (64/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 16 persons, 799.3ms
# video 1/1 (65/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 16 persons, 948.1ms
# video 1/1 (66/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 16 persons, 1026.0ms
# video 1/1 (67/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 16 persons, 757.3ms
# video 1/1 (68/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 15 persons, 886.3ms
# video 1/1 (69/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 16 persons, 771.0ms
# video 1/1 (70/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 17 persons, 734.4ms
# video 1/1 (71/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 19 persons, 761.6ms
# video 1/1 (72/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 16 persons, 779.5ms
# video 1/1 (73/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 17 persons, 748.9ms
# video 1/1 (74/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 17 persons, 758.2ms
# video 1/1 (75/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 16 persons, 765.2ms
# video 1/1 (76/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 14 persons, 701.9ms
# video 1/1 (77/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 16 persons, 769.0ms
# video 1/1 (78/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 14 persons, 770.4ms
# video 1/1 (79/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 12 persons, 825.6ms
# video 1/1 (80/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 13 persons, 811.4ms
# video 1/1 (81/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 15 persons, 876.6ms
# video 1/1 (82/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 16 persons, 869.8ms
# video 1/1 (83/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 15 persons, 788.9ms
# video 1/1 (84/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 16 persons, 819.9ms
# video 1/1 (85/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 16 persons, 811.5ms
# video 1/1 (86/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 16 persons, 744.0ms
# video 1/1 (87/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 16 persons, 747.4ms
# video 1/1 (88/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 15 persons, 730.0ms
# video 1/1 (89/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 16 persons, 754.6ms
# video 1/1 (90/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 15 persons, 784.8ms
# video 1/1 (91/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 14 persons, 1069.6ms
# video 1/1 (92/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 12 persons, 805.1ms
# video 1/1 (93/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 12 persons, 736.4ms
# video 1/1 (94/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 16 persons, 870.9ms
# video 1/1 (95/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 15 persons, 750.4ms
# video 1/1 (96/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 16 persons, 829.0ms
# video 1/1 (97/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 15 persons, 754.0ms
# video 1/1 (98/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 14 persons, 798.9ms
# video 1/1 (99/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 16 persons, 711.5ms
# video 1/1 (100/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 15 persons, 769.7ms
# video 1/1 (101/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 16 persons, 762.3ms
# video 1/1 (102/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 13 persons, 768.5ms
# video 1/1 (103/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 13 persons, 816.0ms
# video 1/1 (104/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 15 persons, 730.6ms
# video 1/1 (105/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 15 persons, 950.2ms
# video 1/1 (106/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 14 persons, 739.7ms
# video 1/1 (107/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 15 persons, 713.7ms
# video 1/1 (108/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 15 persons, 712.5ms
# video 1/1 (109/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 11 persons, 738.2ms
# video 1/1 (110/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 12 persons, 720.8ms
# video 1/1 (111/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 14 persons, 765.2ms
# video 1/1 (112/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 13 persons, 892.5ms
# video 1/1 (113/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 12 persons, 690.4ms
# video 1/1 (114/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 12 persons, 763.4ms
# video 1/1 (115/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 16 persons, 761.7ms
# video 1/1 (116/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 16 persons, 774.4ms
# video 1/1 (117/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 15 persons, 736.1ms
# video 1/1 (118/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 15 persons, 753.7ms
# video 1/1 (119/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 14 persons, 758.5ms
# video 1/1 (120/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 12 persons, 725.9ms
# video 1/1 (121/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 10 persons, 763.2ms
# video 1/1 (122/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 11 persons, 720.0ms
# video 1/1 (123/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 12 persons, 751.7ms
# video 1/1 (124/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 13 persons, 738.7ms
# video 1/1 (125/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 13 persons, 733.3ms
# video 1/1 (126/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 14 persons, 881.5ms
# video 1/1 (127/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 15 persons, 1115.2ms
# video 1/1 (128/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 16 persons, 1420.8ms
# video 1/1 (129/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 15 persons, 895.6ms
# video 1/1 (130/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 16 persons, 944.1ms
# video 1/1 (131/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 16 persons, 897.1ms
# video 1/1 (132/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 15 persons, 784.4ms
# video 1/1 (133/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 16 persons, 1039.3ms
# video 1/1 (134/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 18 persons, 1059.8ms
# video 1/1 (135/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 16 persons, 1015.9ms
# video 1/1 (136/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 16 persons, 1033.2ms
# video 1/1 (137/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 12 persons, 1022.9ms
# video 1/1 (138/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 12 persons, 1142.2ms
# video 1/1 (139/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 11 persons, 1112.6ms
# video 1/1 (140/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 11 persons, 1078.2ms
# video 1/1 (141/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 11 persons, 1054.6ms
# video 1/1 (142/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 13 persons, 1113.0ms
# video 1/1 (143/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 18 persons, 1068.6ms
# video 1/1 (144/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 16 persons, 1061.9ms
# video 1/1 (145/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 14 persons, 1107.0ms
# video 1/1 (146/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 14 persons, 1054.2ms
# video 1/1 (147/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 16 persons, 2229.6ms
# video 1/1 (148/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 16 persons, 2947.7ms
# video 1/1 (149/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 16 persons, 1816.4ms
# video 1/1 (150/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 14 persons, 1256.0ms
# video 1/1 (151/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 16 persons, 1347.2ms
# video 1/1 (152/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 17 persons, 1019.1ms
# video 1/1 (153/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 18 persons, 986.7ms
# video 1/1 (154/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 16 persons, 1122.6ms
# video 1/1 (155/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 18 persons, 988.6ms
# video 1/1 (156/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 20 persons, 2231.4ms
# video 1/1 (157/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 19 persons, 1486.3ms
# video 1/1 (158/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 18 persons, 959.8ms
# video 1/1 (159/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 15 persons, 961.1ms
# video 1/1 (160/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 16 persons, 882.5ms
# video 1/1 (161/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 17 persons, 1044.9ms
# video 1/1 (162/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 16 persons, 1360.8ms
# video 1/1 (163/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 16 persons, 924.3ms
# video 1/1 (164/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 17 persons, 1180.3ms
# video 1/1 (165/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 16 persons, 916.2ms
# video 1/1 (166/228) /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4: 384x640 15 persons, 1250.5ms

# %% [markdown]
# # GET Dataset

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="4YFYl0cqYo11ij1eu1yZ")
project = rf.workspace("loicaudl").project("audldiscdetection")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# Requirement already satisfied: roboflow in /home/julianzu/miniconda3/envs/ComputerVision/lib/python3.11/site-packages (1.1.27)
# Requirement already satisfied: certifi==2023.7.22 in /home/julianzu/miniconda3/envs/ComputerVision/lib/python3.11/site-packages (from roboflow) (2023.7.22)
# Requirement already satisfied: chardet==4.0.0 in /home/julianzu/miniconda3/envs/ComputerVision/lib/python3.11/site-packages (from roboflow) (4.0.0)
# Requirement already satisfied: cycler==0.10.0 in /home/julianzu/miniconda3/envs/ComputerVision/lib/python3.11/site-packages (from roboflow) (0.10.0)
# Requirement already satisfied: idna==2.10 in /home/julianzu/miniconda3/envs/ComputerVision/lib/python3.11/site-packages (from roboflow) (2.10)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/julianzu/miniconda3/envs/ComputerVision/lib/python3.11/site-packages (from roboflow) (1.4.5)
# Requirement already satisfied: matplotlib in /home/julianzu/miniconda3/envs/ComputerVision/lib/python3.11/site-packages (from roboflow) (3.8.2)
# Requirement already satisfied: numpy>=1.18.5 in /home/julianzu/miniconda3/envs/ComputerVision/lib/python3.11/site-packages (from roboflow) (1.26.4)
# Requirement already satisfied: opencv-python-headless==4.8.0.74 in /home/julianzu/miniconda3/envs/ComputerVision/lib/python3.11/site-packages (from roboflow) (4.8.0.74)
# Requirement already satisfied: Pillow>=7.1.2 in /home/julianzu/miniconda3/envs/ComputerVision/lib/python3.11/site-packages (from roboflow) (10.2.0)
# Requirement already satisfied: python-dateutil in /home/julianzu/miniconda3/envs/ComputerVision/lib/python3.11/site-packages (from roboflow) (2.8.2)
# Requirement already satisfied: python-dotenv in /home/julianzu/miniconda3/envs/ComputerVision/lib/python3.11/site-packages (from roboflow) (1.0.1)
# Requirement already satisfied: requests in /home/julianzu/miniconda3/envs/ComputerVision/lib/python3.11/site-packages (from roboflow) (2.31.0)
# Requirement already satisfied: six in /home/julianzu/miniconda3/envs/ComputerVision/lib/python3.11/site-packages (from roboflow) (1.16.0)
# Requirement already satisfied: urllib3>=1.26.6 in /home/julianzu/miniconda3/envs/ComputerVision/lib/python3.11/site-packages (from roboflow) (1.26.18)
# Requirement already satisfied: tqdm>=4.41.0 in /home/julianzu/miniconda3/envs/ComputerVision/lib/python3.11/site-packages (from roboflow) (4.65.0)
# Requirement already satisfied: PyYAML>=5.3.1 in /home/julianzu/miniconda3/envs/ComputerVision/lib/python3.11/site-packages (from roboflow) (6.0.1)
# Requirement already satisfied: requests-toolbelt in /home/julianzu/miniconda3/envs/ComputerVision/lib/python3.11/site-packages (from roboflow) (1.0.0)
# Requirement already satisfied: python-magic in /home/julianzu/miniconda3/envs/ComputerVision/lib/python3.11/site-packages (from roboflow) (0.4.27)
# Requirement already satisfied: contourpy>=1.0.1 in /home/julianzu/miniconda3/envs/ComputerVision/lib/python3.11/site-packages (from matplotlib->roboflow) (1.2.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/julianzu/miniconda3/envs/ComputerVision/lib/python3.11/site-packages (from matplotlib->roboflow) (4.48.1)
# Requirement already satisfied: packaging>=20.0 in /home/julianzu/miniconda3/envs/ComputerVision/lib/python3.11/site-packages (from matplotlib->roboflow) (23.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/julianzu/miniconda3/envs/ComputerVision/lib/python3.11/site-packages (from matplotlib->roboflow) (3.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/julianzu/miniconda3/envs/ComputerVision/lib/python3.11/site-packages (from requests->roboflow) (2.0.4)
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.196 is required but found version=8.1.10, to fix: `pip install ultralytics==8.0.196`
# Downloading Dataset Version Zip in AUDLDiscDetection-1 to yolov8:: 100%|██████████| 7585/7585 [00:17<00:00, 434.00it/s]
# Extracting Dataset Version Zip to AUDLDiscDetection-1 in yolov8:: 100%|██████████| 370/370 [00:01<00:00, 324.79it/s]

# %%
import shutil

shutil.move('Analytics/Ultilitycs/test 08 may/AUDLDiscDetection-1/train',
            'Analytics/Ultilitycs/test 08 may/AUDLDiscDetection-1/AUDLDiscDetection-1/train')

shutil.move('Analytics/Ultilitycs/test 08 may/AUDLDiscDetection-1/test',
            'Analytics/Ultilitycs/test 08 may/AUDLDiscDetection-1/AUDLDiscDetection-1/test')

shutil.move('Analytics/Ultilitycs/test 08 may/AUDLDiscDetection-1/valid',
            'Analytics/Ultilitycs/test 08 may/AUDLDiscDetection-1/AUDLDiscDetection-1/valid')

# %% [markdown]
# # Trainig

# %%
dataset.location
# Out:
# '/home/julianzu/Analytics/Ultilitycs/test 08 may/AUDLDiscDetection-1'

# %%
# !yolo task = detect mode = train model = yolov8n.pt data = {dataset.location}/data.yaml epochs = 100 imgsz = 640

# %%
from ultralytics import YOLO

# %%
model = YOLO('/home/julianzu/Analytics/Ultilitycs/test 08 may/models/best.pt')

results = model.predict('/home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/Captura de pantalla 2024-05-12 213020.png', save = True)
print(results[0])
for box in results[0].boxes:
    print(box)
# Out:
# image 1/1 /home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/Captura de pantalla 2024-05-12 213020.png: 352x640 1 Disc, 16 Players, 772.4ms
# Speed: 65.3ms preprocess, 772.4ms inference, 23.4ms postprocess per image at shape (1, 3, 352, 640)
# Results saved to runs/detect/predict14
# ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'Disc', 1: 'Player'}
# obb: None
# orig_img: array([[[111, 124, 111],
#         [111, 124, 111],
#         [111, 124, 111],
#         ...,
#         [117, 134, 124],
#         [116, 133, 123],
#         [117, 134, 123]],
#
#        [[111, 124, 111],
#         [111, 124, 111],
#         [111, 124, 111],
#         ...,
#         [117, 134, 124],
#         [116, 133, 122],
#         [115, 133, 122]],
#
#        [[111, 124, 111],
#         [111, 124, 111],
#         [111, 124, 111],
#         ...,
#         [117, 134, 123],
#         [116, 133, 122],
#         [115, 132, 122]],
#
#        ...,
#
#        [[ 97, 110,  98],
#         [ 96, 109,  97],
#         [ 96, 109,  97],
#         ...,
#         [103, 119, 106],
#         [103, 118, 106],
#         [103, 118, 106]],
#
#        [[ 98, 111,  99],
#         [ 98, 111,  99],
#         [ 98, 111,  99],
#         ...,
#         [102, 117, 105],
#         [102, 117, 105],
#         [102, 117, 104]],
#
#        [[ 99, 112,  99],
#         [ 99, 112, 100],
#         [100, 113, 101],
#         ...,
#         [101, 117, 104],
#         [101, 116, 104],
#         [101, 117, 104]]], dtype=uint8)
# orig_shape: (399, 756)
# path: '/home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/Captura de pantalla 2024-05-12 213020.png'
# probs: None
# save_dir: 'runs/detect/predict14'
# speed: {'preprocess': 65.26851654052734, 'inference': 772.3569869995117, 'postprocess': 23.38099479675293}
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([1.])
# conf: tensor([0.8340])
# data: tensor([[ 35.4718, 242.6362,  67.4486, 300.5695,   0.8340,   1.0000]])
# id: None
# is_track: False
# orig_shape: (399, 756)
# shape: torch.Size([1, 6])
# xywh: tensor([[ 51.4602, 271.6028,  31.9768,  57.9334]])
# xywhn: tensor([[0.0681, 0.6807, 0.0423, 0.1452]])
# xyxy: tensor([[ 35.4718, 242.6362,  67.4486, 300.5695]])
# xyxyn: tensor([[0.0469, 0.6081, 0.0892, 0.7533]])
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([1.])
# conf: tensor([0.8196])
# data: tensor([[557.9148,  67.8665, 586.0513, 117.1916,   0.8196,   1.0000]])
# id: None
# is_track: False
# orig_shape: (399, 756)
# shape: torch.Size([1, 6])
# xywh: tensor([[571.9830,  92.5290,  28.1365,  49.3251]])
# xywhn: tensor([[0.7566, 0.2319, 0.0372, 0.1236]])
# xyxy: tensor([[557.9148,  67.8665, 586.0513, 117.1916]])
# xyxyn: tensor([[0.7380, 0.1701, 0.7752, 0.2937]])
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([1.])
# conf: tensor([0.8188])
# data: tensor([[296.8728, 194.7812, 325.4764, 257.4381,   0.8188,   1.0000]])
# id: None
# is_track: False
# orig_shape: (399, 756)
# shape: torch.Size([1, 6])
# xywh: tensor([[311.1746, 226.1097,  28.6036,  62.6569]])
# xywhn: tensor([[0.4116, 0.5667, 0.0378, 0.1570]])
# xyxy: tensor([[296.8728, 194.7812, 325.4764, 257.4381]])
# xyxyn: tensor([[0.3927, 0.4882, 0.4305, 0.6452]])
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([1.])
# conf: tensor([0.8056])
# data: tensor([[164.4229, 151.5916, 194.1793, 206.8239,   0.8056,   1.0000]])
# id: None
# is_track: False
# orig_shape: (399, 756)
# shape: torch.Size([1, 6])
# xywh: tensor([[179.3011, 179.2077,  29.7564,  55.2323]])
# xywhn: tensor([[0.2372, 0.4491, 0.0394, 0.1384]])
# xyxy: tensor([[164.4229, 151.5916, 194.1793, 206.8239]])
# xyxyn: tensor([[0.2175, 0.3799, 0.2569, 0.5184]])
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([1.])
# conf: tensor([0.7158])
# data: tensor([[319.2485, 203.8030, 348.0651, 255.3294,   0.7158,   1.0000]])
# id: None
# is_track: False
# orig_shape: (399, 756)
# shape: torch.Size([1, 6])
# xywh: tensor([[333.6568, 229.5662,  28.8166,  51.5263]])
# xywhn: tensor([[0.4413, 0.5754, 0.0381, 0.1291]])
# xyxy: tensor([[319.2485, 203.8030, 348.0651, 255.3294]])
# xyxyn: tensor([[0.4223, 0.5108, 0.4604, 0.6399]])
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([1.])
# conf: tensor([0.7015])
# data: tensor([[326.8875,  34.8533, 353.6426,  89.6354,   0.7015,   1.0000]])
# id: None
# is_track: False
# orig_shape: (399, 756)
# shape: torch.Size([1, 6])
# xywh: tensor([[340.2650,  62.2444,  26.7552,  54.7821]])
# xywhn: tensor([[0.4501, 0.1560, 0.0354, 0.1373]])
# xyxy: tensor([[326.8875,  34.8533, 353.6426,  89.6354]])
# xyxyn: tensor([[0.4324, 0.0874, 0.4678, 0.2247]])
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([1.])
# conf: tensor([0.6988])
# data: tensor([[461.5027, 131.5129, 490.1324, 177.7843,   0.6988,   1.0000]])
# id: None
# is_track: False
# orig_shape: (399, 756)
# shape: torch.Size([1, 6])
# xywh: tensor([[475.8175, 154.6486,  28.6297,  46.2715]])
# xywhn: tensor([[0.6294, 0.3876, 0.0379, 0.1160]])
# xyxy: tensor([[461.5027, 131.5129, 490.1324, 177.7843]])
# xyxyn: tensor([[0.6105, 0.3296, 0.6483, 0.4456]])
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([1.])
# conf: tensor([0.6720])
# data: tensor([[507.1510,  42.8855, 534.2244,  90.9383,   0.6720,   1.0000]])
# id: None
# is_track: False
# orig_shape: (399, 756)
# shape: torch.Size([1, 6])
# xywh: tensor([[520.6877,  66.9119,  27.0734,  48.0527]])
# xywhn: tensor([[0.6887, 0.1677, 0.0358, 0.1204]])
# xyxy: tensor([[507.1510,  42.8855, 534.2244,  90.9383]])
# xyxyn: tensor([[0.6708, 0.1075, 0.7066, 0.2279]])
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([1.])
# conf: tensor([0.6518])
# data: tensor([[503.6244, 131.0952, 528.5444, 182.1537,   0.6518,   1.0000]])
# id: None
# is_track: False
# orig_shape: (399, 756)
# shape: torch.Size([1, 6])
# xywh: tensor([[516.0844, 156.6244,  24.9201,  51.0585]])
# xywhn: tensor([[0.6827, 0.3925, 0.0330, 0.1280]])
# xyxy: tensor([[503.6244, 131.0952, 528.5444, 182.1537]])
# xyxyn: tensor([[0.6662, 0.3286, 0.6991, 0.4565]])
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([1.])
# conf: tensor([0.6327])
# data: tensor([[340.2421, 289.3056, 381.4156, 365.2550,   0.6327,   1.0000]])
# id: None
# is_track: False
# orig_shape: (399, 756)
# shape: torch.Size([1, 6])
# xywh: tensor([[360.8288, 327.2803,  41.1735,  75.9494]])
# xywhn: tensor([[0.4773, 0.8203, 0.0545, 0.1903]])
# xyxy: tensor([[340.2421, 289.3056, 381.4156, 365.2550]])
# xyxyn: tensor([[0.4501, 0.7251, 0.5045, 0.9154]])
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([1.])
# conf: tensor([0.5995])
# data: tensor([[321.9341,  35.2297, 345.2264,  89.7502,   0.5995,   1.0000]])
# id: None
# is_track: False
# orig_shape: (399, 756)
# shape: torch.Size([1, 6])
# xywh: tensor([[333.5803,  62.4899,  23.2923,  54.5205]])
# xywhn: tensor([[0.4412, 0.1566, 0.0308, 0.1366]])
# xyxy: tensor([[321.9341,  35.2297, 345.2264,  89.7502]])
# xyxyn: tensor([[0.4258, 0.0883, 0.4566, 0.2249]])
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([1.])
# conf: tensor([0.5661])
# data: tensor([[371.2436,  32.2347, 405.2734,  81.5921,   0.5661,   1.0000]])
# id: None
# is_track: False
# orig_shape: (399, 756)
# shape: torch.Size([1, 6])
# xywh: tensor([[388.2585,  56.9134,  34.0298,  49.3574]])
# xywhn: tensor([[0.5136, 0.1426, 0.0450, 0.1237]])
# xyxy: tensor([[371.2436,  32.2347, 405.2734,  81.5921]])
# xyxyn: tensor([[0.4911, 0.0808, 0.5361, 0.2045]])
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([1.])
# conf: tensor([0.4756])
# data: tensor([[378.0315,  34.8363, 407.7346,  80.5623,   0.4756,   1.0000]])
# id: None
# is_track: False
# orig_shape: (399, 756)
# shape: torch.Size([1, 6])
# xywh: tensor([[392.8831,  57.6993,  29.7031,  45.7260]])
# xywhn: tensor([[0.5197, 0.1446, 0.0393, 0.1146]])
# xyxy: tensor([[378.0315,  34.8363, 407.7346,  80.5623]])
# xyxyn: tensor([[0.5000, 0.0873, 0.5393, 0.2019]])
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.])
# conf: tensor([0.4213])
# data: tensor([[5.4362e+02, 2.2279e+02, 5.5471e+02, 2.3129e+02, 4.2127e-01, 0.0000e+00]])
# id: None
# is_track: False
# orig_shape: (399, 756)
# shape: torch.Size([1, 6])
# xywh: tensor([[549.1664, 227.0399,  11.0957,   8.5032]])
# xywhn: tensor([[0.7264, 0.5690, 0.0147, 0.0213]])
# xyxy: tensor([[543.6185, 222.7883, 554.7142, 231.2915]])
# xyxyn: tensor([[0.7191, 0.5584, 0.7337, 0.5797]])
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([1.])
# conf: tensor([0.3862])
# data: tensor([[335.6755, 265.5140, 380.1184, 365.5215,   0.3862,   1.0000]])
# id: None
# is_track: False
# orig_shape: (399, 756)
# shape: torch.Size([1, 6])
# xywh: tensor([[357.8969, 315.5178,  44.4429, 100.0074]])
# xywhn: tensor([[0.4734, 0.7908, 0.0588, 0.2506]])
# xyxy: tensor([[335.6755, 265.5140, 380.1184, 365.5215]])
# xyxyn: tensor([[0.4440, 0.6654, 0.5028, 0.9161]])
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([1.])
# conf: tensor([0.3537])
# data: tensor([[3.3463e+02, 2.6448e+02, 3.6397e+02, 3.4182e+02, 3.5365e-01, 1.0000e+00]])
# id: None
# is_track: False
# orig_shape: (399, 756)
# shape: torch.Size([1, 6])
# xywh: tensor([[349.3003, 303.1509,  29.3369,  77.3438]])
# xywhn: tensor([[0.4620, 0.7598, 0.0388, 0.1938]])
# xyxy: tensor([[334.6318, 264.4790, 363.9687, 341.8228]])
# xyxyn: tensor([[0.4426, 0.6629, 0.4814, 0.8567]])
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([1.])
# conf: tensor([0.2836])
# data: tensor([[3.3452e+02, 2.6569e+02, 3.6286e+02, 3.2085e+02, 2.8358e-01, 1.0000e+00]])
# id: None
# is_track: False
# orig_shape: (399, 756)
# shape: torch.Size([1, 6])
# xywh: tensor([[348.6902, 293.2692,  28.3395,  55.1583]])
# xywhn: tensor([[0.4612, 0.7350, 0.0375, 0.1382]])
# xyxy: tensor([[334.5204, 265.6901, 362.8599, 320.8484]])
# xyxyn: tensor([[0.4425, 0.6659, 0.4800, 0.8041]])

# %%
import cv2
def read_video(video_path):
    cap = cv2.VideoCapture(video_path)
    frames = []
    while True:
        ret, frame = cap.read()
        if not ret:
            break
        frames.append(frame)
    return frames

def save_video(output_video_frames, output_path):
    fourcc = cv2.VideoWriter_fourcc(*'XVID')
    out = cv2.VideoWriter(output_path, fourcc, 24, (output_video_frames[0].shape[1], output_video_frames[0].shape[0]))
    for frame in output_video_frames:
        out.write(frame)
    out.release()

# %%
#read video

video_frames = read_video('/home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4')

#save video

#save_video(video_frames, '/home/julianzu/Analytics/Ultilitycs/test 08 may/output_videos/drone trimmed.avi')

# %% [markdown]
# # Tracker

# %%
# !pip install supervision
# Out:
# Collecting supervision
#   Downloading supervision-0.20.0-py3-none-any.whl.metadata (13 kB)
# Collecting defusedxml<0.8.0,>=0.7.1 (from supervision)
#   Downloading defusedxml-0.7.1-py2.py3-none-any.whl.metadata (32 kB)
# Requirement already satisfied: matplotlib>=3.6.0 in /home/julianzu/miniconda3/envs/ComputerVision/lib/python3.11/site-packages (from supervision) (3.8.2)
# Requirement already satisfied: numpy>=1.21.2 in /home/julianzu/miniconda3/envs/ComputerVision/lib/python3.11/site-packages (from supervision) (1.26.4)
# Requirement already satisfied: opencv-python-headless>=4.5.5.64 in /home/julianzu/miniconda3/envs/ComputerVision/lib/python3.11/site-packages (from supervision) (4.8.0.74)
# Requirement already satisfied: pillow>=9.4 in /home/julianzu/miniconda3/envs/ComputerVision/lib/python3.11/site-packages (from supervision) (10.2.0)
# Requirement already satisfied: pyyaml>=5.3 in /home/julianzu/miniconda3/envs/ComputerVision/lib/python3.11/site-packages (from supervision) (6.0.1)
# Requirement already satisfied: scipy<2.0.0,>=1.10.0 in /home/julianzu/miniconda3/envs/ComputerVision/lib/python3.11/site-packages (from supervision) (1.11.4)
# Requirement already satisfied: contourpy>=1.0.1 in /home/julianzu/miniconda3/envs/ComputerVision/lib/python3.11/site-packages (from matplotlib>=3.6.0->supervision) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /home/julianzu/miniconda3/envs/ComputerVision/lib/python3.11/site-packages (from matplotlib>=3.6.0->supervision) (0.10.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/julianzu/miniconda3/envs/ComputerVision/lib/python3.11/site-packages (from matplotlib>=3.6.0->supervision) (4.48.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/julianzu/miniconda3/envs/ComputerVision/lib/python3.11/site-packages (from matplotlib>=3.6.0->supervision) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /home/julianzu/miniconda3/envs/ComputerVision/lib/python3.11/site-packages (from matplotlib>=3.6.0->supervision) (23.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/julianzu/miniconda3/envs/ComputerVision/lib/python3.11/site-packages (from matplotlib>=3.6.0->supervision) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /home/julianzu/miniconda3/envs/ComputerVision/lib/python3.11/site-packages (from matplotlib>=3.6.0->supervision) (2.8.2)
# Requirement already satisfied: six in /home/julianzu/miniconda3/envs/ComputerVision/lib/python3.11/site-packages (from cycler>=0.10->matplotlib>=3.6.0->supervision) (1.16.0)
# Downloading supervision-0.20.0-py3-none-any.whl (110 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.0/111.0 kB 3.0 MB/s eta 0:00:00
# Downloading defusedxml-0.7.1-py2.py3-none-any.whl (25 kB)
# Installing collected packages: defusedxml, supervision
# Successfully installed defusedxml-0.7.1 supervision-0.20.0

# %%
from ultralytics import YOLO
import supervision as sv
import pickle
import os
import sys
import cv2
import numpy as np

# %%
#bbox utils:
def get_center_of_bbox(bbox):
    x1,y1,x2,y2 = bbox
    return int((x1+x2)/2), int((y1+y2)/2)

def get_bbox_width(bbox):
    return bbox[2]-bbox[0]

# %%
class Tracker:
    def __init__(self, model_path):
        self.model = YOLO(model_path)
        self.tracker = sv.ByteTrack()


    def detect_frames(self, frames):
        batch_size = 20
        detections = []
        for i in range(0,len(frames),batch_size):
            detections_batch = self.model.predict(frames[i:i+batch_size], conf = 0.1)
            detections += detections_batch
        return detections

    def get_object_tracks(self, frames, read_from_stub = False, stub_path = None):

        if read_from_stub and stub_path is not None and os.path.exists(stub_path):
            with open(stub_path,'rb') as f:
                tracks = pickle.load(f)
            return tracks

        detections = self.detect_frames(frames)

        tracks = {
            "Disc":[],
            "Player":[]
        }

        for frame_num, detection in enumerate(detections):
            cls_names = detection.names
            cls_names_inv = {v:k for k,v in cls_names.items()}
            

            #covert to supervision detection format
            detection_supervision = sv.Detections.from_ultralytics(detection)


            #track objects:
            detection_with_tracks = self.tracker.update_with_detections(detection_supervision)


            tracks["Disc"].append({})
            tracks["Player"].append({})
            
            for frame_detection in detection_with_tracks:
                bbox = frame_detection[0].tolist()
                cls_id = frame_detection[3]
                track_id = frame_detection[4]

                if cls_id == cls_names_inv['Player']:
                    tracks["Player"][frame_num][track_id] = {"bbox":bbox}


            for frame_detection in detection_supervision:
                bbox = frame_detection[0].tolist()
                cls_id = frame_detection[3]

                if cls_id == cls_names_inv['Disc']:
                    tracks["Disc"][frame_num][1] = {"bbox":bbox}


        if stub_path is not None:
            with open(stub_path,'wb') as f:
                pickle.dump(tracks,f)

        return tracks

    def draw_ellipse(self, frame, bbox, color, track_id = None):
        y2 = int(bbox[3])
        x_center, _ = get_center_of_bbox(bbox)
        width = get_bbox_width(bbox)

        cv2.ellipse(
            frame,
            center=(x_center,y2),
            axes=(int(width), int(0.35*width)),
            angle=0.0,
            startAngle=-45,
            endAngle=235,
            color = color,
            thickness=2,
            lineType=cv2.LINE_4
        )

        rectangle_width = 40
        rectangle_height=20
        x1_rect = x_center - rectangle_width//2
        x2_rect = x_center + rectangle_width//2
        y1_rect = (y2- rectangle_height//2) +15
        y2_rect = (y2+ rectangle_height//2) +15

        if track_id is not None:
            cv2.rectangle(frame,
                          (int(x1_rect),int(y1_rect) ),
                          (int(x2_rect),int(y2_rect)),
                          color,
                          cv2.FILLED)
            
            x1_text = x1_rect+12
            if track_id > 99:
                x1_text -=10
            
            cv2.putText(
                frame,
                f"{track_id}",
                (int(x1_text),int(y1_rect+15)),
                cv2.FONT_HERSHEY_SIMPLEX,
                0.6,
                (0,0,0),
                2
            )


        return frame



    def draw_triangle(self,frame,bbox,color):
        y= int(bbox[1])
        x,_ = get_center_of_bbox(bbox)

        triangle_points = np.array([
            [x,y],
            [x-10,y-20],
            [x+10,y-20],
        ])
        cv2.drawContours(frame, [triangle_points],0,color, cv2.FILLED)
        cv2.drawContours(frame, [triangle_points],0,(0,0,0), 2)

        return frame


    def draw_annotations(self,video_frames, tracks):
        output_video_frames = []
        for frame_num, frame in enumerate(video_frames):
            frame = frame.copy()

            player_dict = tracks["Player"][frame_num]
            disc_dict = tracks["Disc"][frame_num]

            #draw Players

            for track_id, player in player_dict.items():
                frame = self.draw_ellipse(frame, player["bbox"],(0,0,255), track_id)

            #draw Disc:

            for track_id, Disc in disc_dict.items():
                frame = self.draw_triangle(frame, Disc["bbox"],(0,255,0))


            output_video_frames.append(frame)

        return output_video_frames

# %%
#read video

video_frames = read_video('/home/julianzu/Analytics/Ultilitycs/test 08 may/input_videos/drone trimmed.mp4')

#initialize tracker:
tracker = Tracker('/home/julianzu/Analytics/Ultilitycs/test 08 may/models/best.pt')
tracks = tracker.get_object_tracks(video_frames, read_from_stub = True, stub_path = 'stubs/track_stubs.pkl' )


#save cropped image of a player
for track_id, player in tracks['Player'][0].items():
    bbox = player
    frame =video_frames[0]

    #crop bbox from frame
    cropped_image = frame[bbox[1]:bbox[3], bbox[0]:bbox[2]]

    #save the cropped image
    cv2.imwrite()

#draw output
##draw object tracks
output_video_frames = tracker.draw_annotations(video_frames, tracks)

#save video

save_video(output_video_frames, '/home/julianzu/Analytics/Ultilitycs/test 08 may/output_videos/drone trimmed.avi')

# %% [markdown]
# # Color Assignament
